# %%
from matplotlib import font_manager, rc
font_path = "data/malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
print(font_name)
rc('font', family=font_name)
# Out:
# Malgun Gothic

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns
import scipy.stats as stats
from mlxtend.frequent_patterns import apriori

# %%
df = pd.read_csv('data/국내 데이터센터(수) 증가 추이_한국데이터센터연합회.csv', header=0, index_col='년도', encoding = "utf-8")
display(df)
# Out:
#       비상업용  상업용(일반)  상업용(통신)   전체
# 년도
# 2002    46       10        9   65
# 2003    49       10        9   68
# 2004    52       10        9   71
# 2005    56       10        9   75
# 2006    60       11       12   83
# 2007    66       11       12   89
# 2008    74       12       13   99
# 2009    78       14       14  106
# 2010    82       16       14  112
# 2011    86       17       15  118
# 2012    87       19       16  122
# 2013    93       19       16  128
# 2014    95       19       16  130
# 2015   103       20       19  142
# 2016   108       21       20  149
# 2017   112       21       20  153
# 2018   114       21       20  155
# 2019   115       23       20  158

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (16, 9)
plt.rcParams['font.size'] = 12

x = np.arange(2002, 2020)
y1 = df.iloc[0:, 0:3]
y2 = df.iloc[0:, 3:4]

# %%
fig, ax1 = plt.subplots()

ax1.plot(x, y2, '-s', color='green')
ax1.set_xlabel('년도')
ax1.set_ylabel('개수')
ax1.set_ylim(50, 160)
ax1.set_xlim(2001,2020)
ax1.tick_params(axis='both', direction='in')

ax2.bar(x, y1, stacked = True, label='부문별 개수')
ax2.tick_params(axis='y', direction='in')

ax1.set_zorder(ax2.get_zorder() + 10)
ax1.patch.set_visible(False)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-84fc20631a90> in <module>
#       8 ax1.tick_params(axis='both', direction='in')
#       9
# ---> 10 ax2.bar(x, y1, stacked = True, label='부문별 개수')
#      11 ax2.tick_params(axis='y', direction='in')
#      12
#
# NameError: name 'ax2' is not defined
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
fig, ax1 = plt.subplots()

ax1.plot(x, y2, '-s', color='green')
ax1.set_xlabel('년도')
ax1.set_ylabel('개수')
ax1.set_ylim(50, 160)
ax1.set_xlim(2001,2020)
ax1.tick_params(axis='both', direction='in')

a_bottom = y1.iloc[0:,0:1]
b_bottom =

ax2.bar(x, y1.iloc[0:,0:1])
ax2.bar(x, y1.iloc[0:,1:2], bottom = y1.iloc[0:,0:1])
ax2.bar(x, y1.iloc[0:,2:3], bottom = y1.iloc[0:,1:2])
ax2.tick_params(axis='y', direction='in')

ax1.set_zorder(ax2.get_zorder() + 10)
ax1.patch.set_visible(False)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()
# Out:
#   File "<ipython-input-6-1f943e1403d1>", line 11
#     b_bottom =
#               ^
# SyntaxError: invalid syntax

# %%
dt = pd.read_csv('data/2015-2019 통합 데이터파일.csv', header=0, index_col= "년도", encoding = "utf-8")
display(dt)
# Out:
#       1인당 전력소비량(단위: kWh)  GDP 대비 전력소비량(단위: GWh/십억 원)  1인당 에너지 소비량(단위: 백만 TOE)  \
# 년도
# 2015                9555                       0.292                    215.4
# 2016                9699                       0.286                    221.9
# 2017                9869                       0.277                    230.6
# 2018               10195                       0.277                    233.4
# 2019               10039                       0.271                    231.4
#
#       온실가스 총 배출량(단위: 백만 톤)  국내 OTT 시장 매출액 추이(단위: 억 원)  \
# 년도
# 2015                 692.5                       2587
# 2016                 693.5                       3069
# 2017                 709.7                       4149
# 2018                 727.6                       5136
# 2019                 708.2                       6345
#
#       온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)  \
# 년도
# 2015                                    2.4
# 2016                                    2.9
# 2017                                    3.3
# 2018                                    3.6
# 2019                                    4.3
#
#       온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)  국내 전체 데이터센터(수)
# 년도
# 2015                                     15.70             142
# 2016                                     24.17             149
# 2017                                     30.85             153
# 2018                                     36.00             155
# 2019                                     49.40             158

# %%
# 정규성 검정x Kendall
sns.set(font="Malgun Gothic", 
        rc={"axes.unicode_minus":False})

corr = dt.corr(method = 'kendall')
plt.figure(figsize = (18, 12))
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
# 정규성 검정 Pearson
re = dt.corr(method = "pearson")
display(re)
# Out:
#                                           1인당 전력소비량(단위: kWh)  \
# 1인당 전력소비량(단위: kWh)                                  1.000000
# GDP 대비 전력소비량(단위: GWh/십억 원)                         -0.855921
# 1인당 에너지 소비량(단위: 백만 TOE)                             0.939897
# 온실가스 총 배출량(단위: 백만 톤)                                0.936921
# 국내 OTT 시장 매출액 추이(단위: 억 원)                           0.873138
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)               0.840723
# 온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)            0.824271
# 국내 전체 데이터센터(수)                                      0.891529
#
#                                           GDP 대비 전력소비량(단위: GWh/십억 원)  \
# 1인당 전력소비량(단위: kWh)                                         -0.855921
# GDP 대비 전력소비량(단위: GWh/십억 원)                                  1.000000
# 1인당 에너지 소비량(단위: 백만 TOE)                                    -0.936985
# 온실가스 총 배출량(단위: 백만 톤)                                       -0.698381
# 국내 OTT 시장 매출액 추이(단위: 억 원)                                  -0.948506
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)                      -0.966678
# 온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)                   -0.959450
# 국내 전체 데이터센터(수)                                             -0.981195
#
#                                           1인당 에너지 소비량(단위: 백만 TOE)  \
# 1인당 전력소비량(단위: kWh)                                       0.939897
# GDP 대비 전력소비량(단위: GWh/십억 원)                              -0.936985
# 1인당 에너지 소비량(단위: 백만 TOE)                                  1.000000
# 온실가스 총 배출량(단위: 백만 톤)                                     0.873294
# 국내 OTT 시장 매출액 추이(단위: 억 원)                                0.854532
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)                    0.858500
# 온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)                 0.839971
# 국내 전체 데이터센터(수)                                           0.948485
#
#                                           온실가스 총 배출량(단위: 백만 톤)  \
# 1인당 전력소비량(단위: kWh)                                    0.936921
# GDP 대비 전력소비량(단위: GWh/십억 원)                           -0.698381
# 1인당 에너지 소비량(단위: 백만 TOE)                               0.873294
# 온실가스 총 배출량(단위: 백만 톤)                                  1.000000
# 국내 OTT 시장 매출액 추이(단위: 억 원)                             0.690691
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)                 0.627269
# 온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)              0.603628
# 국내 전체 데이터센터(수)                                        0.718363
#
#                                           국내 OTT 시장 매출액 추이(단위: 억 원)  \
# 1인당 전력소비량(단위: kWh)                                         0.873138
# GDP 대비 전력소비량(단위: GWh/십억 원)                                -0.948506
# 1인당 에너지 소비량(단위: 백만 TOE)                                    0.854532
# 온실가스 총 배출량(단위: 백만 톤)                                       0.690691
# 국내 OTT 시장 매출액 추이(단위: 억 원)                                  1.000000
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)                      0.986895
# 온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)                   0.986040
# 국내 전체 데이터센터(수)                                             0.933550
#
#                                           온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)  \
# 1인당 전력소비량(단위: kWh)                                                     0.840723
# GDP 대비 전력소비량(단위: GWh/십억 원)                                            -0.966678
# 1인당 에너지 소비량(단위: 백만 TOE)                                                0.858500
# 온실가스 총 배출량(단위: 백만 톤)                                                   0.627269
# 국내 OTT 시장 매출액 추이(단위: 억 원)                                              0.986895
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)                                  1.000000
# 온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)                               0.999367
# 국내 전체 데이터센터(수)                                                         0.962572
#
#                                           온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)  \
# 1인당 전력소비량(단위: kWh)                                                        0.824271
# GDP 대비 전력소비량(단위: GWh/십억 원)                                               -0.959450
# 1인당 에너지 소비량(단위: 백만 TOE)                                                   0.839971
# 온실가스 총 배출량(단위: 백만 톤)                                                      0.603628
# 국내 OTT 시장 매출액 추이(단위: 억 원)                                                 0.986040
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)                                     0.999367
# 온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)                                  1.000000
# 국내 전체 데이터센터(수)                                                            0.953176
#
#                                           국내 전체 데이터센터(수)
# 1인당 전력소비량(단위: kWh)                              0.891529
# GDP 대비 전력소비량(단위: GWh/십억 원)                     -0.981195
# 1인당 에너지 소비량(단위: 백만 TOE)                         0.948485
# 온실가스 총 배출량(단위: 백만 톤)                            0.718363
# 국내 OTT 시장 매출액 추이(단위: 억 원)                       0.933550
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)           0.962572
# 온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)        0.953176
# 국내 전체 데이터센터(수)                                  1.000000

# %%
dt
# Out:
#       1인당 전력소비량(단위: kWh)  GDP 대비 전력소비량(단위: GWh/십억 원)  1인당 에너지 소비량(단위: 백만 TOE)  \
# 년도
# 2015                9555                       0.292                    215.4
# 2016                9699                       0.286                    221.9
# 2017                9869                       0.277                    230.6
# 2018               10195                       0.277                    233.4
# 2019               10039                       0.271                    231.4
#
#       온실가스 총 배출량(단위: 백만 톤)  국내 OTT 시장 매출액 추이(단위: 억 원)  \
# 년도
# 2015                 692.5                       2587
# 2016                 693.5                       3069
# 2017                 709.7                       4149
# 2018                 727.6                       5136
# 2019                 708.2                       6345
#
#       온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)  \
# 년도
# 2015                                    2.4
# 2016                                    2.9
# 2017                                    3.3
# 2018                                    3.6
# 2019                                    4.3
#
#       온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)  국내 전체 데이터센터(수)
# 년도
# 2015                                     15.70             142
# 2016                                     24.17             149
# 2017                                     30.85             153
# 2018                                     36.00             155
# 2019                                     49.40             158

# %%
np.corrcoef(dt['1인당 전력소비량(단위: kWh)'], dt['GDP 대비 전력소비량(단위: GWh/십억 원)'])
# Out:
# array([[ 1.        , -0.85592064],
#        [-0.85592064,  1.        ]])

# %%
np.corrcoef(dt['1인당 전력소비량(단위: kWh)'], dt['1인당 에너지 소비량(단위: 백만 TOE)'])
# Out:
# array([[1.        , 0.93989654],
#        [0.93989654, 1.        ]])

# %%
np.corrcoef(dt['1인당 전력소비량(단위: kWh)'], dt['온실가스 총 배출량(단위: 백만 톤)'])
# Out:
# array([[1.        , 0.93692149],
#        [0.93692149, 1.        ]])

# %%
np.corrcoef(dt['1인당 전력소비량(단위: kWh)'], dt['국내 OTT 시장 매출액 추이(단위: 억 원)'])
# Out:
# array([[1.        , 0.87313758],
#        [0.87313758, 1.        ]])

# %%
np.corrcoef(dt['1인당 전력소비량(단위: kWh)'], dt['온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)'])
# Out:
# array([[1.        , 0.84072273],
#        [0.84072273, 1.        ]])

# %%
dt
# Out:
#       1인당 전력소비량(단위: kWh)  GDP 대비 전력소비량(단위: GWh/십억 원)  1인당 에너지 소비량(단위: 백만 TOE)  \
# 년도
# 2015                9555                       0.292                    215.4
# 2016                9699                       0.286                    221.9
# 2017                9869                       0.277                    230.6
# 2018               10195                       0.277                    233.4
# 2019               10039                       0.271                    231.4
#
#       온실가스 총 배출량(단위: 백만 톤)  국내 OTT 시장 매출액 추이(단위: 억 원)  \
# 년도
# 2015                 692.5                       2587
# 2016                 693.5                       3069
# 2017                 709.7                       4149
# 2018                 727.6                       5136
# 2019                 708.2                       6345
#
#       온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)  \
# 년도
# 2015                                    2.4
# 2016                                    2.9
# 2017                                    3.3
# 2018                                    3.6
# 2019                                    4.3
#
#       온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)  국내 전체 데이터센터(수)
# 년도
# 2015                                     15.70             142
# 2016                                     24.17             149
# 2017                                     30.85             153
# 2018                                     36.00             155
# 2019                                     49.40             158

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

x_data = dt[['1인당 전력소비량(단위: kWh)', '1인당 에너지 소비량(단위: 백만 TOE)', '국내 OTT 시장 매출액 추이(단위: 억 원)']]
target = dt[['온실가스 총 배출량(단위: 백만 톤)']]
res = sm.OLS(target, x_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     온실가스 총 배출량(단위: 백만 톤)   R-squared (uncentered):                   1.000
# Model:                              OLS   Adj. R-squared (uncentered):              1.000
# Method:                   Least Squares   F-statistic:                          3.695e+04
# Date:                  Fri, 23 Apr 2021   Prob (F-statistic):                    2.71e-05
# Time:                          13:05:04   Log-Likelihood:                         -12.589
# No. Observations:                     5   AIC:                                      31.18
# Df Residuals:                         2   BIC:                                      30.01
# Df Model:                             3
# Covariance Type:              nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# 1인당 전력소비량(단위: kWh)            0.0688      0.021      3.293      0.081      -0.021       0.159
# 1인당 에너지 소비량(단위: 백만 TOE)       0.2029      0.927      0.219      0.847      -3.785       4.191
# 국내 OTT 시장 매출액 추이(단위: 억 원)    -0.0045      0.002     -2.379      0.140      -0.013       0.004
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.910
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.743
# Skew:                          -0.852   Prob(JB):                        0.690
# Kurtosis:                       2.188   Cond. No.                     4.71e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x2_data = dt[['온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)', '온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)', '국내 전체 데이터센터(수)']]
target2 = dt[['온실가스 총 배출량(단위: 백만 톤)']]
res = sm.OLS(target2, x2_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     온실가스 총 배출량(단위: 백만 톤)   R-squared (uncentered):                   1.000
# Model:                              OLS   Adj. R-squared (uncentered):              1.000
# Method:                   Least Squares   F-statistic:                          1.585e+04
# Date:                  Fri, 23 Apr 2021   Prob (F-statistic):                    6.31e-05
# Time:                          13:05:04   Log-Likelihood:                         -14.704
# No. Observations:                     5   AIC:                                      35.41
# Df Residuals:                         2   BIC:                                      34.24
# Df Model:                             3
# Covariance Type:              nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)      822.4135    368.832      2.230      0.156    -764.540    2409.368
# 온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)   -43.8233     18.922     -2.316      0.147    -125.240      37.593
# 국내 전체 데이터센터(수)                              -4.2231      4.138     -1.021      0.415     -22.027      13.581
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.436
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.429
# Skew:                           0.091   Prob(JB):                        0.807
# Kurtosis:                       1.576   Cond. No.                     1.77e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x3_data = dt[['1인당 전력소비량(단위: kWh)',  '국내 OTT 시장 매출액 추이(단위: 억 원)', '국내 전체 데이터센터(수)']]
target3 = dt[['온실가스 총 배출량(단위: 백만 톤)']]
res = sm.OLS(target3, x3_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     온실가스 총 배출량(단위: 백만 톤)   R-squared (uncentered):                   1.000
# Model:                              OLS   Adj. R-squared (uncentered):              1.000
# Method:                   Least Squares   F-statistic:                          4.708e+04
# Date:                  Fri, 23 Apr 2021   Prob (F-statistic):                    2.12e-05
# Time:                          13:05:05   Log-Likelihood:                         -11.983
# No. Observations:                     5   AIC:                                      29.97
# Df Residuals:                         2   BIC:                                      28.79
# Df Model:                             3
# Covariance Type:              nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# 1인당 전력소비량(단위: kWh)            0.0844      0.014      5.961      0.027       0.023       0.145
# 국내 OTT 시장 매출액 추이(단위: 억 원)    -0.0030      0.002     -1.389      0.299      -0.012       0.006
# 국내 전체 데이터센터(수)               -0.7557      0.968     -0.781      0.517      -4.920       3.409
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.171
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.251
# Skew:                           0.437   Prob(JB):                        0.882
# Kurtosis:                       2.334   Cond. No.                     5.55e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.55e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x4_data = dt[['온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)', '국내 전체 데이터센터(수)']]
target4 = dt[['온실가스 총 배출량(단위: 백만 톤)']]
res = sm.OLS(target4, x4_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     온실가스 총 배출량(단위: 백만 톤)   R-squared (uncentered):                   1.000
# Model:                              OLS   Adj. R-squared (uncentered):              1.000
# Method:                   Least Squares   F-statistic:                              9686.
# Date:                  Fri, 23 Apr 2021   Prob (F-statistic):                    1.93e-06
# Time:                          13:05:06   Log-Likelihood:                         -17.963
# No. Observations:                     5   AIC:                                      39.93
# Df Residuals:                         3   BIC:                                      39.14
# Df Model:                             2
# Covariance Type:              nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)   -31.6599      9.640     -3.284      0.046     -62.340      -0.980
# 국내 전체 데이터센터(수)                            5.3550      0.214     25.032      0.000       4.674       6.036
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.427
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.408
# Skew:                          -0.030   Prob(JB):                        0.815
# Kurtosis:                       1.602   Cond. No.                         288.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x5_data = dt[['온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)']]
target = dt[['온실가스 총 배출량(단위: 백만 톤)']]
res = sm.OLS(target, x5_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     온실가스 총 배출량(단위: 백만 톤)   R-squared (uncentered):                   0.968
# Model:                              OLS   Adj. R-squared (uncentered):              0.959
# Method:                   Least Squares   F-statistic:                              119.1
# Date:                  Fri, 23 Apr 2021   Prob (F-statistic):                    0.000400
# Time:                          13:05:09   Log-Likelihood:                         -31.329
# No. Observations:                     5   AIC:                                      64.66
# Df Residuals:                         4   BIC:                                      64.27
# Df Model:                             1
# Covariance Type:              nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)   206.6852     18.940     10.913      0.000     154.100     259.270
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.540
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.229
# Skew:                          -0.328   Prob(JB):                        0.892
# Kurtosis:                       2.182   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x6_data = dt[['국내 OTT 시장 매출액 추이(단위: 억 원)']]
target = dt[['온실가스 총 배출량(단위: 백만 톤)']]
res = sm.OLS(target, x6_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     온실가스 총 배출량(단위: 백만 톤)   R-squared (uncentered):                   0.914
# Model:                              OLS   Adj. R-squared (uncentered):              0.892
# Method:                   Least Squares   F-statistic:                              42.26
# Date:                  Fri, 23 Apr 2021   Prob (F-statistic):                     0.00289
# Time:                          13:05:10   Log-Likelihood:                         -33.776
# No. Observations:                     5   AIC:                                      69.55
# Df Residuals:                         4   BIC:                                      69.16
# Df Model:                             1
# Covariance Type:              nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# 국내 OTT 시장 매출액 추이(단위: 억 원)     0.1510      0.023      6.501      0.003       0.087       0.215
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.393
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.407
# Skew:                          -0.361   Prob(JB):                        0.816
# Kurtosis:                       1.803   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x7_data = dt[['온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)']]
target = dt[['온실가스 총 배출량(단위: 백만 톤)']]
res = sm.OLS(target, x7_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     온실가스 총 배출량(단위: 백만 톤)   R-squared (uncentered):                   0.890
# Model:                              OLS   Adj. R-squared (uncentered):              0.863
# Method:                   Least Squares   F-statistic:                              32.38
# Date:                  Fri, 23 Apr 2021   Prob (F-statistic):                     0.00471
# Time:                          13:05:11   Log-Likelihood:                         -34.376
# No. Observations:                     5   AIC:                                      70.75
# Df Residuals:                         4   BIC:                                      70.36
# Df Model:                             1
# Covariance Type:              nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# 온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)    20.0601      3.525      5.691      0.005      10.273      29.848
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.484
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.257
# Skew:                          -0.368   Prob(JB):                        0.879
# Kurtosis:                       2.167   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x8_data = dt[['1인당 전력소비량(단위: kWh)']]
target = dt[['온실가스 총 배출량(단위: 백만 톤)']]
res = sm.OLS(target, x8_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     온실가스 총 배출량(단위: 백만 톤)   R-squared (uncentered):                   1.000
# Model:                              OLS   Adj. R-squared (uncentered):              1.000
# Method:                   Least Squares   F-statistic:                          5.083e+04
# Date:                  Fri, 23 Apr 2021   Prob (F-statistic):                    2.32e-09
# Time:                          13:05:12   Log-Likelihood:                         -16.270
# No. Observations:                     5   AIC:                                      34.54
# Df Residuals:                         4   BIC:                                      34.15
# Df Model:                             1
# Covariance Type:              nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# 1인당 전력소비량(단위: kWh)     0.0715      0.000    225.463      0.000       0.071       0.072
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.019
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.196
# Skew:                          -0.243   Prob(JB):                        0.906
# Kurtosis:                       2.159   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x9_data = dt[['국내 전체 데이터센터(수)']]
target = dt[['온실가스 총 배출량(단위: 백만 톤)']]
res = sm.OLS(target, x9_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     온실가스 총 배출량(단위: 백만 톤)   R-squared (uncentered):                   0.999
# Model:                              OLS   Adj. R-squared (uncentered):              0.999
# Method:                   Least Squares   F-statistic:                              5618.
# Date:                  Fri, 23 Apr 2021   Prob (F-statistic):                    1.90e-07
# Time:                          13:05:13   Log-Likelihood:                         -21.775
# No. Observations:                     5   AIC:                                      45.55
# Df Residuals:                         4   BIC:                                      45.16
# Df Model:                             1
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# 국내 전체 데이터센터(수)     4.6611      0.062     74.952      0.000       4.488       4.834
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.236
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.083
# Skew:                           0.090   Prob(JB):                        0.959
# Kurtosis:                       2.395   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x10_data = dt[['온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)']]
target = dt[['1인당 전력소비량(단위: kWh)']]
res = sm.OLS(target, x10_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     1인당 전력소비량(단위: kWh)   R-squared (uncentered):                   0.970
# Model:                            OLS   Adj. R-squared (uncentered):              0.963
# Method:                 Least Squares   F-statistic:                              130.9
# Date:                Fri, 23 Apr 2021   Prob (F-statistic):                    0.000333
# Time:                        13:05:13   Log-Likelihood:                         -44.287
# No. Observations:                   5   AIC:                                      90.57
# Df Residuals:                       4   BIC:                                      90.18
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# 온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)  2893.2313    252.856     11.442      0.000    2191.190    3595.272
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.534
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.235
# Skew:                          -0.322   Prob(JB):                        0.889
# Kurtosis:                       2.155   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x11_data = dt[['온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)']]
target = dt[['1인당 전력소비량(단위: kWh)']]
res = sm.OLS(target, x11_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     1인당 전력소비량(단위: kWh)   R-squared (uncentered):                   0.895
# Model:                            OLS   Adj. R-squared (uncentered):              0.869
# Method:                 Least Squares   F-statistic:                              34.15
# Date:                Fri, 23 Apr 2021   Prob (F-statistic):                     0.00428
# Time:                        13:05:14   Log-Likelihood:                         -47.445
# No. Observations:                   5   AIC:                                      96.89
# Df Residuals:                       4   BIC:                                      96.50
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# 온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)   281.1942     48.120      5.844      0.004     147.591     414.797
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.481
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.261
# Skew:                          -0.365   Prob(JB):                        0.878
# Kurtosis:                       2.152   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x12_data = dt[['국내 OTT 시장 매출액 추이(단위: 억 원)']]
target = dt[['1인당 전력소비량(단위: kWh)']]
res = sm.OLS(target, x12_data).fit()
res.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/stats/stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     1인당 전력소비량(단위: kWh)   R-squared (uncentered):                   0.918
# Model:                            OLS   Adj. R-squared (uncentered):              0.897
# Method:                 Least Squares   F-statistic:                              44.70
# Date:                Fri, 23 Apr 2021   Prob (F-statistic):                     0.00260
# Time:                        13:05:17   Log-Likelihood:                         -46.834
# No. Observations:                   5   AIC:                                      95.67
# Df Residuals:                       4   BIC:                                      95.28
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# 국내 OTT 시장 매출액 추이(단위: 억 원)     2.1157      0.316      6.686      0.003       1.237       2.994
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.392
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.413
# Skew:                          -0.350   Prob(JB):                        0.814
# Kurtosis:                       1.779   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
dt
# Out:
#       1인당 전력소비량(단위: kWh)  GDP 대비 전력소비량(단위: GWh/십억 원)  1인당 에너지 소비량(단위: 백만 TOE)  \
# 년도
# 2015                9555                       0.292                    215.4
# 2016                9699                       0.286                    221.9
# 2017                9869                       0.277                    230.6
# 2018               10195                       0.277                    233.4
# 2019               10039                       0.271                    231.4
#
#       온실가스 총 배출량(단위: 백만 톤)  국내 OTT 시장 매출액 추이(단위: 억 원)  \
# 년도
# 2015                 692.5                       2587
# 2016                 693.5                       3069
# 2017                 709.7                       4149
# 2018                 727.6                       5136
# 2019                 708.2                       6345
#
#       온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)  \
# 년도
# 2015                                    2.4
# 2016                                    2.9
# 2017                                    3.3
# 2018                                    3.6
# 2019                                    4.3
#
#       온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)  국내 전체 데이터센터(수)
# 년도
# 2015                                     15.70             142
# 2016                                     24.17             149
# 2017                                     30.85             153
# 2018                                     36.00             155
# 2019                                     49.40             158

# %%
# 다중회귀모델 계수
res.params
# Out:
# 국내 OTT 시장 매출액 추이(단위: 억 원)    2.115686
# dtype: float64

# %%
sns.pairplot(x_data)
plt.show()

# %%
# 연관분석?
frequent_itemsets = apriori(dt, min_support = 0.5, use_colnames=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-8611d30037b4> in <module>
#       1 # 연관분석?
# ----> 2 frequent_itemsets = apriori(dt, min_support = 0.5, use_colnames=True)
#
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/mlxtend/frequent_patterns/apriori.py in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     236                          'Got %s.' % min_support)
#     237
# --> 238     fpc.valid_input_check(df)
#     239
#     240     if hasattr(df, "sparse"):
#
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py in valid_input_check(df)
#     114             s = ('The allowed values for a DataFrame'
#     115                  ' are True, False, 0, 1. Found value %s' % (val))
# --> 116             raise ValueError(s)
#     117
#     118
#
# ValueError: The allowed values for a DataFrame are True, False, 0, 1. Found value 9555.0

# %%
dt
# Out:
#       1인당 전력소비량(단위: kWh)  GDP 대비 전력소비량(단위: GWh/십억 원)  1인당 에너지 소비량(단위: 백만 TOE)  \
# 년도
# 2015                9555                       0.292                    215.4
# 2016                9699                       0.286                    221.9
# 2017                9869                       0.277                    230.6
# 2018               10195                       0.277                    233.4
# 2019               10039                       0.271                    231.4
#
#       온실가스 총 배출량(단위: 백만 톤)  국내 OTT 시장 매출액 추이(단위: 억 원)  \
# 년도
# 2015                 692.5                       2587
# 2016                 693.5                       3069
# 2017                 709.7                       4149
# 2018                 727.6                       5136
# 2019                 708.2                       6345
#
#       온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)  \
# 년도
# 2015                                    2.4
# 2016                                    2.9
# 2017                                    3.3
# 2018                                    3.6
# 2019                                    4.3
#
#       온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)  국내 전체 데이터센터(수)
# 년도
# 2015                                     15.70             142
# 2016                                     24.17             149
# 2017                                     30.85             153
# 2018                                     36.00             155
# 2019                                     49.40             158

# %%
dtf = pd.read_csv('data/2015-2019 통합 데이터파일.csv', header=0,  encoding = "utf-8")

# %%
dtf
# Out:
#      년도  1인당 전력소비량(단위: kWh)  GDP 대비 전력소비량(단위: GWh/십억 원)  \
# 0  2015                9555                       0.292
# 1  2016                9699                       0.286
# 2  2017                9869                       0.277
# 3  2018               10195                       0.277
# 4  2019               10039                       0.271
#
#    1인당 에너지 소비량(단위: 백만 TOE)  온실가스 총 배출량(단위: 백만 톤)  국내 OTT 시장 매출액 추이(단위: 억 원)  \
# 0                    215.4                 692.5                       2587
# 1                    221.9                 693.5                       3069
# 2                    230.6                 709.7                       4149
# 3                    233.4                 727.6                       5136
# 4                    231.4                 708.2                       6345
#
#    온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)  \
# 0                                    2.4
# 1                                    2.9
# 2                                    3.3
# 3                                    3.6
# 4                                    4.3
#
#    온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)  국내 전체 데이터센터(수)
# 0                                     15.70             142
# 1                                     24.17             149
# 2                                     30.85             153
# 3                                     36.00             155
# 4                                     49.40             158

# %%
from sklearn.linear_model import LinearRegression

X = dtf["년도"]
y = dtf["온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)"]
plt.plot(X, y, 'o')
plt.show()

# %%
line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
line_fitter.predict([[2020]])
# Out:
# array([4.65])

# %%
plt.plot(X, y, 'o')
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)))
plt.show()

# %%
from sklearn.model_selection import train_test_split

x = dtf[['1인당 전력소비량(단위: kWh)', '1인당 에너지 소비량(단위: 백만 TOE)', '온실가스 총 배출량(단위: 백만 톤)', '국내 OTT 시장 매출액 추이(단위: 억 원)', '온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)', '온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)', '국내 전체 데이터센터(수)']]
y = dtf[['년도']]
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2, random_state=0)

# %%
print("X_train 크기: {}".format(x_train.shape))
print("y_train 크기: {}".format(y_train.shape))
# Out:
# X_train 크기: (4, 7)
# y_train 크기: (4, 1)

# %%
print("X_test 크기: {}".format(x_test.shape))
print("y_test 크기: {}".format(y_test.shape))
# Out:
# X_test 크기: (1, 7)
# y_test 크기: (1, 1)

# %%
pd.plotting.scatter_matrix(dtf, c=y_train, figsize=(15, 15), marker='o',
hist_kwds={'1인당 전력소비량(단위: kWh)': 20}, s=60, alpha=.8)
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/misc.py:61: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.hist(values, **hist_kwds)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-317cf2192ef0> in <module>
#       1 pd.plotting.scatter_matrix(dtf, c=y_train, figsize=(15, 15), marker='o',
# ----> 2 hist_kwds={'1인당 전력소비량(단위: kWh)': 20}, s=60, alpha=.8)
#
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/pandas/plotting/_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     137         hist_kwds=hist_kwds,
#     138         range_padding=range_padding,
# --> 139         **kwargs,
#     140     )
#     141
#
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      59                 # Deal with the diagonal by drawing a histogram there.
#      60                 if diagonal == "hist":
# ---> 61                     ax.hist(values, **hist_kwds)
#      62
#      63                 elif diagonal in ("kde", "density"):
#
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1350     def inner(ax, *args, data=None, **kwargs):
#    1351         if data is None:
# -> 1352             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1353
#    1354         bound = new_sig.bind(ax, *args, **kwargs)
#
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6888             if patch:
#    6889                 p = patch[0]
# -> 6890                 p.update(kwargs)
#    6891                 if lbl is not None:
#    6892                     p.set_label(lbl)
#
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#    1060                     func = getattr(self, f"set_{k}", None)
#    1061                     if not callable(func):
# -> 1062                         raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                              f"has no property {k!r}")
#    1064                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property '1인당 전력소비량(단위: kwh)'

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(x_train, y_train)

# %%
prediction = knn.predict(X_new)
print("예측: {}".format(prediction))
print("예측한 타깃의 이름: {}".format(
iris_dataset['target_names'][prediction]))

# %%
y_pred = knn.predict(X_test)
print("테스트 세트에 대한 예측값:\n {}".format(y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-20156cbc49ff> in <module>
# ----> 1 y_pred = knn.predict(X_test)
#       2 print("테스트 세트에 대한 예측값:\n {}".format(y_pred))
#
# NameError: name 'knn' is not defined

# %%
dtf
# Out:
#      년도  1인당 전력소비량(단위: kWh)  GDP 대비 전력소비량(단위: GWh/십억 원)  \
# 0  2015                9555                       0.292
# 1  2016                9699                       0.286
# 2  2017                9869                       0.277
# 3  2018               10195                       0.277
# 4  2019               10039                       0.271
#
#    1인당 에너지 소비량(단위: 백만 TOE)  온실가스 총 배출량(단위: 백만 톤)  국내 OTT 시장 매출액 추이(단위: 억 원)  \
# 0                    215.4                 692.5                       2587
# 1                    221.9                 693.5                       3069
# 2                    230.6                 709.7                       4149
# 3                    233.4                 727.6                       5136
# 4                    231.4                 708.2                       6345
#
#    온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)  \
# 0                                    2.4
# 1                                    2.9
# 2                                    3.3
# 3                                    3.6
# 4                                    4.3
#
#    온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)  국내 전체 데이터센터(수)
# 0                                     15.70             142
# 1                                     24.17             149
# 2                                     30.85             153
# 3                                     36.00             155
# 4                                     49.40             158

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(mlr.coef_)
# Out:
# [[ 0.00301203  0.01022958 -0.02918504  0.00050966  0.00110513  0.01903958
#    0.01735554]]

# %%
plt.scatter(dtf[['1인당 전력소비량(단위: kWh)']], dtf[['국내 OTT 시장 매출액 추이(단위: 억 원)']], alpha=0.4)
plt.show()

# %%
print(mlr.score(x_train, y_train))
# Out:
# 1.0

# %%
import scipy.stats as stats

stats.pearsonr(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-a89191273e9f> in <module>
#       1 import scipy.stats as stats
#       2
# ----> 3 stats.pearsonr(x, y)
#
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3517         return dtype(np.sign(x[1] - x[0])*np.sign(y[1] - y[0])), 1.0
#    3518
# -> 3519     xmean = x.mean(dtype=dtype)
#    3520     ymean = y.mean(dtype=dtype)
#    3521
#
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
#
# TypeError: No loop matching the specified signature and casting was found for ufunc add

# %%
dtf
# Out:
#      년도  1인당 전력소비량(단위: kWh)  GDP 대비 전력소비량(단위: GWh/십억 원)  \
# 0  2015                9555                       0.292
# 1  2016                9699                       0.286
# 2  2017                9869                       0.277
# 3  2018               10195                       0.277
# 4  2019               10039                       0.271
#
#    1인당 에너지 소비량(단위: 백만 TOE)  온실가스 총 배출량(단위: 백만 톤)  국내 OTT 시장 매출액 추이(단위: 억 원)  \
# 0                    215.4                 692.5                       2587
# 1                    221.9                 693.5                       3069
# 2                    230.6                 709.7                       4149
# 3                    233.4                 727.6                       5136
# 4                    231.4                 708.2                       6345
#
#    온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)  \
# 0                                    2.4
# 1                                    2.9
# 2                                    3.3
# 3                                    3.6
# 4                                    4.3
#
#    온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)  국내 전체 데이터센터(수)
# 0                                     15.70             142
# 1                                     24.17             149
# 2                                     30.85             153
# 3                                     36.00             155
# 4                                     49.40             158

# %%
adf = pd.read_csv('data/1인당및 GDP전력소비량(2019년).csv', header=0,  encoding = "utf-8")
adf
# Out:
#       년도  1인당 전력소비량  GDP 대비 전력소비량
# 0   1990       2202         0.471
# 1   2000       5067         0.368
# 2   2010       8883         0.328
# 3   2011       9142         0.328
# 4   2012       9331         0.324
# 5   2013       9285         0.316
# 6   2014       9305         0.306
# 7   2015       9555         0.292
# 8   2016       9699         0.286
# 9   2017       9869         0.277
# 10  2018      10195         0.277
# 11  2019      10039         0.271

# %%
x = adf.iloc[:,0:1]
y = adf.iloc[:,1:2]
plt.plot(x, y, 'o')
plt.show()

# %%
line_fitter = LinearRegression()
line_fitter.fit(x.values.reshape(-1,1), y)
# Out:
# LinearRegression()

# %%
line_fitter.predict([[2020]])
# Out:
# array([[11024.69603045]])

# %%
line_fitter.coef_
# Out:
# array([[283.08907015]])

# %%
line_fitter.intercept_
# Out:
# array([-560815.22566612])

# %%
plt.plot(x, y, 'o')
plt.plot(x,line_fitter.predict(x.values.reshape(-1,1)))
plt.show()

# %%
bdf = pd.read_csv('data/온실가스 총배출량.csv', header=0,  encoding = "utf-8")
bdf
# Out:
#    Unnamed: 0  총배출량(백만 톤 CO2eq.)
# 0        2010              656.3
# 1        2011              684.9
# 2        2012              688.3
# 3        2013              697.4
# 4        2014              691.9
# 5        2015              692.5
# 6        2016              693.5
# 7        2017              709.7
# 8        2018              727.6
# 9        2019              708.2

# %%
x = bdf.iloc[:, 0:1]
y = bdf.iloc[:, 1:2]
plt.plot(x, y, 'o')
plt.show()

# %%
line_fitter = LinearRegression()
line_fitter.fit(x.values.reshape(-1,1), y)
line_fitter.predict([[2020]])
# Out:
# array([[723.76]])

# %%
line_fitter.coef_
# Out:
# array([[5.22363636]])

# %%
line_fitter.intercept_
# Out:
# array([-9827.98545455])

# %%
plt.plot(x, y, 'o')
plt.plot(x,line_fitter.predict(x.values.reshape(-1,1)))
plt.show()

# %%
cdf = pd.read_csv('data/1인당 에너지 소비량.csv', header=0,  encoding = "utf-8")
cdf
# Out:
#      년도  1인당 에너지 소비량
# 0  2011        205.2
# 1  2012        207.0
# 2  2013        208.4
# 3  2014        210.4
# 4  2015        215.4
# 5  2016        221.9
# 6  2017        230.6
# 7  2018        233.4
# 8  2019        231.4

# %%
x = cdf.iloc[:, 0:1]
y = cdf.iloc[:, 1:2]
plt.plot(x, y, 'o')
plt.show()

# %%
line_fitter = LinearRegression()
line_fitter.fit(x.values.reshape(-1,1), y)
line_fitter.predict([[2020]])
# Out:
# array([[238.18055556]])

# %%
line_fitter.coef_
# Out:
# array([[3.99833333]])

# %%
line_fitter.intercept_
# Out:
# array([-7838.45277778])

# %%
plt.plot(x, y, 'o')
plt.plot(x,line_fitter.predict(x.values.reshape(-1,1)))
plt.show()

# %%
Ddf = pd.read_csv('data/국내 OTT 시장 매출액 추이_방송통신위원회.csv', header=0,  encoding = "utf-8")
Ddf
# Out:
#      년도  매출액(단위:억원) - 2019년은 추정치
# 0  2012                     1085
# 1  2013                     1490
# 2  2014                     1926
# 3  2015                     2587
# 4  2016                     3069
# 5  2017                     4149
# 6  2018                     5136
# 7  2019                     6345

# %%
x = Ddf.iloc[:, 0:1]
y = Ddf.iloc[:, 1:2]
plt.plot(x, y, 'o')
plt.show()

# %%
line_fitter = LinearRegression()
line_fitter.fit(x.values.reshape(-1,1), y)
line_fitter.predict([[2020]])
# Out:
# array([[6555.57142857]])

# %%
line_fitter.coef_
# Out:
# array([[740.48809524]])

# %%
line_fitter.intercept_
# Out:
# array([-1489230.38095238])

# %%
plt.plot(x, y, 'o')
plt.plot(x,line_fitter.predict(x.values.reshape(-1,1)))
plt.show()

# %%
edf = pd.read_csv('data/국내 데이터센터(수) 증가 추이_한국데이터센터연합회.csv', header=0,  encoding = "utf-8")
edf
# Out:
#       년도  비상업용  상업용(일반)  상업용(통신)   전체
# 0   2002    46       10        9   65
# 1   2003    49       10        9   68
# 2   2004    52       10        9   71
# 3   2005    56       10        9   75
# 4   2006    60       11       12   83
# 5   2007    66       11       12   89
# 6   2008    74       12       13   99
# 7   2009    78       14       14  106
# 8   2010    82       16       14  112
# 9   2011    86       17       15  118
# 10  2012    87       19       16  122
# 11  2013    93       19       16  128
# 12  2014    95       19       16  130
# 13  2015   103       20       19  142
# 14  2016   108       21       20  149
# 15  2017   112       21       20  153
# 16  2018   114       21       20  155
# 17  2019   115       23       20  158

# %%
x = edf.iloc[:, 0:1]
y = edf.iloc[:, 4:5]
plt.plot(x, y, 'o')
plt.show()

# %%
line_fitter = LinearRegression()
line_fitter.fit(x.values.reshape(-1,1), y)
line_fitter.predict([[2020]])
# Out:
# array([[169.08496732]])

# %%
line_fitter.coef_
# Out:
# array([[5.96800826]])

# %%
line_fitter.intercept_
# Out:
# array([-11886.29170967])

# %%
plt.plot(x, y, 'o')
plt.plot(x,line_fitter.predict(x.values.reshape(-1,1)))
plt.show()

# %%
dtf
# Out:
#      년도  1인당 전력소비량(단위: kWh)  GDP 대비 전력소비량(단위: GWh/십억 원)  \
# 0  2015                9555                       0.292
# 1  2016                9699                       0.286
# 2  2017                9869                       0.277
# 3  2018               10195                       0.277
# 4  2019               10039                       0.271
#
#    1인당 에너지 소비량(단위: 백만 TOE)  온실가스 총 배출량(단위: 백만 톤)  국내 OTT 시장 매출액 추이(단위: 억 원)  \
# 0                    215.4                 692.5                       2587
# 1                    221.9                 693.5                       3069
# 2                    230.6                 709.7                       4149
# 3                    233.4                 727.6                       5136
# 4                    231.4                 708.2                       6345
#
#    온라인동영상제공서비스(OTT) 이용 빈도 주 평균 일수(단위: 일)  \
# 0                                    2.4
# 1                                    2.9
# 2                                    3.3
# 3                                    3.6
# 4                                    4.3
#
#    온라인동영상제공서비스(OTT) 이용 빈도 주 5회 이상 비율(단위: %)  국내 전체 데이터센터(수)
# 0                                     15.70             142
# 1                                     24.17             149
# 2                                     30.85             153
# 3                                     36.00             155
# 4                                     49.40             158

# %%
from sklearn.model_selection import train_test_split

x = dtf[['1인당 전력소비량(단위: kWh)', '1인당 에너지 소비량(단위: 백만 TOE)', '국내 OTT 시장 매출액 추이(단위: 억 원)', '국내 전체 데이터센터(수)']]
y = dtf[['온실가스 총 배출량(단위: 백만 톤)']]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
my_2020 = [[11024.69603045, 238.18055556,  6555.57142857, 169]]
my_predict = mlr.predict(my_2020)

# %%
y_predict = mlr.predict(x_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_predict, alpha=0.4)
plt.show()

# %%
((y - y_predict) ** 2).sum()
# Out:
# 온실가스 총 배출량(단위: 백만 톤)    1092.958812
# dtype: float64

# %%
print(mlr.score(x_train, y_train))
# Out:
# 1.0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( dtf['data'], iris_dataset['target'], random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(x_train, y_train)
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-fdc926e502f6> in <module>
# ----> 1 knn.fit(x_train, y_train)
#
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py in fit(self, X, y)
#    1144             self.outputs_2d_ = True
#    1145
# -> 1146         check_classification_targets(y)
#    1147         self.classes_ = []
#    1148         self._y = np.empty(y.shape, dtype=np.int)
#
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171                       'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'continuous'
